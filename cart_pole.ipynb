# %%
import torch
import torch.nn as nn
from torch.distributions.categorical import Categorical
from torch.optim import Adam
import numpy as np
import gym
from gym.spaces import Discrete, Box
import matplotlib.pyplot as plt
import time
from agent import *
plt.style.use('seaborn')

# %%
def plot_agent_reward(r,eps,discount,lr_):
    fig, ax = plt.subplots(1,figsize=(14,10))
    ax.set_title(f"Agent Reward over {eps}eps with $\gamma$={discount} and a learning rate:{lr_}", fontsize=20)
    ax.set_xlabel("Number of Episodes",fontsize = 14)
    ax.set_ylabel("Episode Reward",fontsize = 14)
    ax.plot(r, label = 'Agent\'s reward')
    ax.plot([np.mean(r[i:i+50]) for i in range(eps - 50)], ls='--', lw=2,color='red',label = '50eps moving average')
    ax.legend(fontsize = 14)
    plt.show()

# %%
env = gym.make('CartPole-v0')
input_dim = env.observation_space.shape[0]
output_dim = env.action_space.n

# %% [markdown]
# # 1. Monte-Carlo Cart-Pole

# %%
eps = 1000
discount = 1
lr_ = 0.001
t1 = time.time()
r = train(eps,discount,lr_, input_dim, output_dim, env, MC = True)
plot_agent_reward(r,eps,discount,lr_)
print("Total Run Time is {:.2f}s".format(time.time()-t1))
# Out:
# Episode 0 Score: 10.0
# Episode 100 Score: 47.0
# Episode 200 Score: 70.0
# Episode 300 Score: 76.0
# Episode 400 Score: 200.0
# Episode 500 Score: 200.0
# Episode 600 Score: 200.0
# Episode 700 Score: 200.0
# Episode 800 Score: 155.0
# Episode 900 Score: 200.0
# Total Run Time is 184.74s

# %%
eps = 1000
discount =  0.95
lr_ = 0.005
t1 = time.time()
r = train(eps,discount,lr_, input_dim, output_dim, env, MC = True)
plot_agent_reward(r,eps,discount,lr_)
print("Total Run Time is {:.2f}s".format(time.time()-t1))
# Out:
# Episode 0 Score: 13.0
# Episode 100 Score: 173.0
# Episode 200 Score: 155.0
# Episode 300 Score: 200.0
# Episode 400 Score: 177.0
# Episode 500 Score: 173.0
# Episode 600 Score: 185.0
# Episode 700 Score: 189.0
# Episode 800 Score: 200.0
# Episode 900 Score: 200.0
# Total Run Time is 225.95s

# %%
eps = 1000
discount =  0.95
lr_ = 0.01
t1 = time.time()
r = train(eps,discount,lr_, input_dim, output_dim, env, MC = True)
plot_agent_reward(r,eps,discount,lr_)
print("Total Run Time is {:.2f}s".format(time.time()-t1))
# Out:
# Episode 0 Score: 29.0
# Episode 100 Score: 200.0
# Episode 200 Score: 200.0
# Episode 300 Score: 200.0
# Episode 400 Score: 200.0
# Episode 500 Score: 200.0
# Episode 600 Score: 136.0
# Episode 700 Score: 200.0
# Episode 800 Score: 200.0
# Episode 900 Score: 135.0
# Total Run Time is 268.39s

# %% [markdown]
# # 2. TD Cartpole

# %%
eps = 5000
discount = 1
lr_ = 0.001
t1 = time.time()
r = train(eps,discount,lr_, input_dim, output_dim, env, MC = False)
plot_agent_reward(r,eps,discount,lr_)
print("Total Run Time is {:.2f}s".format(time.time()-t1))
# Out:
# Episode 0 Score: 20.0
# Episode 100 Score: 21.0
# Episode 200 Score: 16.0
# Episode 300 Score: 11.0
# Episode 400 Score: 16.0
# Episode 500 Score: 90.0
# Episode 600 Score: 67.0
# Episode 700 Score: 60.0
# Episode 800 Score: 200.0
# Episode 900 Score: 135.0
# Episode 1000 Score: 47.0
# Episode 1100 Score: 56.0
# Episode 1200 Score: 117.0
# Episode 1300 Score: 200.0
# Episode 1400 Score: 70.0
# Episode 1500 Score: 196.0
# Episode 1600 Score: 59.0
# Episode 1700 Score: 146.0
# Episode 1800 Score: 200.0
# Episode 1900 Score: 113.0
# Episode 2000 Score: 200.0
# Episode 2100 Score: 122.0
# Episode 2200 Score: 117.0
# Episode 2300 Score: 200.0
# Episode 2400 Score: 187.0
# Episode 2500 Score: 200.0
# Episode 2600 Score: 170.0
# Episode 2700 Score: 200.0
# Episode 2800 Score: 188.0
# Episode 2900 Score: 200.0
# Episode 3000 Score: 197.0
# Episode 3100 Score: 200.0
# Episode 3200 Score: 152.0
# Episode 3300 Score: 121.0
# Episode 3400 Score: 141.0
# Episode 3500 Score: 147.0
# Episode 3600 Score: 135.0
# Episode 3700 Score: 200.0
# Episode 3800 Score: 200.0
# Episode 3900 Score: 200.0
# Episode 4000 Score: 200.0
# Episode 4100 Score: 200.0
# Episode 4200 Score: 200.0
# Episode 4300 Score: 200.0
# Episode 4400 Score: 200.0
# Episode 4500 Score: 200.0
# Episode 4600 Score: 200.0
# Episode 4700 Score: 200.0
# Episode 4800 Score: 200.0
# Episode 4900 Score: 200.0
# Total Run Time is 1494.75s

# %%
eps = 5000
discount =  0.95
lr_ = 0.005
t1 = time.time()
r = train(eps,discount,lr_, input_dim, output_dim, env, MC = False)
plot_agent_reward(r,eps,discount,lr_)
print("Total Run Time is {:.2f}s".format(time.time()-t1))
# Out:
# Episode 0 Score: 15.0
# Episode 100 Score: 42.0
# Episode 200 Score: 70.0
# Episode 300 Score: 50.0
# Episode 400 Score: 74.0
# Episode 500 Score: 96.0
# Episode 600 Score: 63.0
# Episode 700 Score: 48.0
# Episode 800 Score: 96.0
# Episode 900 Score: 100.0
# Episode 1000 Score: 142.0
# Episode 1100 Score: 200.0
# Episode 1200 Score: 94.0
# Episode 1300 Score: 37.0
# Episode 1400 Score: 58.0
# Episode 1500 Score: 70.0
